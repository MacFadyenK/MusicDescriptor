# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from datasets import load_from_disk

ds = load_from_disk("/content/gdrive/MyDrive/musiccaps_with_audio")

print("Dataset size:", len(ds))
# Out:
# Dataset size: 4204

# %%
sample = ds[3000]

print(sample["audio"])          # see what's stored
print(sample.keys())
# Out:
# <datasets.features._torchcodec.AudioDecoder object at 0x798b82352480>
# dict_keys(['ytid', 'start_s', 'end_s', 'audioset_positive_labels', 'aspect_list', 'caption', 'author_id', 'is_balanced_subset', 'is_audioset_eval', 'audio', 'download_status'])

# %%
audio = sample["audio"]["array"]
sr = sample["audio"]["sampling_rate"]

print(f"Size of audio clip: {audio.shape}")
print(f"Sampling rate: {sr}")
# Out:
# Size of audio clip: (441000,)
# Sampling rate: 44100

# %%
from IPython.display import Audio as IPAudio

IPAudio(sample["audio"]["array"], rate=sample["audio"]["sampling_rate"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(sample['caption'])
# Out:
# This song contains someone playing a blues melody on the acoustic piano along with an e-guitar and an e-bass. The acoustic drums are playing a constant rhythm while male deep voice is backed by higher sounding male voices singing harmonies along with him. Then a male voice starts talking that seems not to be part of the musical composition. This song may be playing in a cafe.
